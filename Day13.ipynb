# %% [markdown]
# <a href="https://colab.research.google.com/github/bezawadachowdary16-lang/python_dsa/blob/main/Day13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class TreeNode:
  def __init__(self,data):
    self,data=data
    self,children=[]
class Tree:
  def __init__(self):
    self,root=None
def add(self,data,parentdata=None):
    node=TreeNode(data)
    if self.root==None:
      self.root=node
    else:
      if parentdata==None:
        self.root

# %% [markdown]
# <a href="https://colab.research.google.com/github/bezawadachowdary16-lang/python_dsa/blob/main/Day9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Two pointers
arr1=[5,6,9,7,4,1,2,3]
arr1.sort()
target=int(input())
left=0
right=len(arr1)-1
while left<right:
    if arr1[left]+arr1[right]==target:
      print(arr1[left],arr1[right])
      break
      found_pair=True
    elif arr1[left]+arr1[right]<target:
      left+=1
    else:
      right-=1
else:
    print("No pair found")
# Out:
# 12345
# No pair found

# %%
#find palindrome or not using two pointers
a=input()
left=0
right=len(a)-1
while left<right:
    if a[left]!=a[right]:
        print("Not a palindrome")
        break
    left+=1
    right-=1
else:
    print("Palindrome")
# Out:
# madam
# Palindrome

# %%
#sum of two pairs using two pointers
arr1=[5,6,9,7,4,1,2,3]
arr1.sort()
target=int(input())
left=0
right=len(arr1)-1
found_pair=False
while left<right:
    if arr1[left]+arr1[right]==target:
      print(arr1[left],arr1[right])
      found_pair=True
      left+=1
      right-=1
    elif arr1[left]+arr1[right]<target:
      left+=1
    else:
      right-=1
if not found_pair:
    print("No pair found")
# Out:
# 12
# 3 9
# 5 7

# %%
#sliding window
def min_subarray_len(nums,target):
  left=0
  right=0
  sub_sum=0
  min_len=float('inf')
  while right<len(nums)
    sub_sum+=nums[right]
    while sub_sum>=target:
        min_len=min(min_len,right-left+1)
        sub_sum-=nums[left]
        left+=
